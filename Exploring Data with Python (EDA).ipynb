# %% [markdown]
# # EDA

# %%
#Importing Libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

pd.set_option('display.max_column', 55)

# %%
#Getting Data
df = pd.read_csv('public_up_to_150k_12_220703.csv')

# %%
df.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  7803247307   04/30/2020            304              PPP
# 1  7890008407   02/12/2021            353              PPS
# 2  8235537001   04/08/2020            304              PPP
# 3  8336827200   04/28/2020            304              PPP
# 4  8497097305   05/01/2020            304              PPP
#
#                                   BorrowerName              BorrowerAddress  \
# 0                                      APEX MD         5310 Twin Hickory Rd
# 1   1ST AMERICAN HOME HEALTH CARE SERVICESINC.  6216 Old Franconia Rd Ste A
# 2             QUALITY LANDSCAPE SOLUTIONS, LLC        14637 HOLDING POND CT
# 3                       EATS NATURAL FOODS INC           708A North MAIN ST
# 4  DETAIL JANITORIAL SERVICES OF VIRGINIA INC.              836 CALLAWAY RD
#
#   BorrowerCity BorrowerState BorrowerZip LoanStatusDate    LoanStatus  Term  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 599879 entries, 0 to 599878
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   LoanNumber                   599879 non-null  int64
#  1   DateApproved                 599879 non-null  object
#  2   SBAOfficeCode                599879 non-null  int64
#  3   ProcessingMethod             599879 non-null  object
#  4   BorrowerName                 599871 non-null  object
#  5   BorrowerAddress              599873 non-null  object
#  6   BorrowerCity                 599874 non-null  object
#  7   BorrowerState                599879 non-null  object
#  8   BorrowerZip                  599874 non-null  object
#  9   LoanStatusDate               549778 non-null  object
#  10  LoanStatus                   599879 non-null  object
#  11  Term                         599879 non-null  int64
# ...

# %%
#checking for nulls
df.isnull().sum()
# Out:
# LoanNumber                          0
# DateApproved                        0
# SBAOfficeCode                       0
# ProcessingMethod                    0
# BorrowerName                        8
# BorrowerAddress                     6
# BorrowerCity                        5
# BorrowerState                       0
# BorrowerZip                         5
# LoanStatusDate                  50101
# LoanStatus                          0
# Term                                0
# SBAGuarantyPercentage               0
# InitialApprovalAmount               0
# CurrentApprovalAmount               0
# UndisbursedAmount                 178
# FranchiseName                  591645
# ServicingLenderLocationID           0
# ServicingLenderName                 0
# ServicingLenderAddress              0
# ServicingLenderCity                 0
# ServicingLenderState                0
# ServicingLenderZip                  0
# RuralUrbanIndicator                 0
# HubzoneIndicator                    0
# ...

# %%
df = df.loc[df['BorrowerName'].notnull()]
df
# Out:
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0       7803247307   04/30/2020            304              PPP
# 1       7890008407   02/12/2021            353              PPS
# 2       8235537001   04/08/2020            304              PPP
# 3       8336827200   04/28/2020            304              PPP
# 4       8497097305   05/01/2020            304              PPP
# ...            ...          ...            ...              ...
# 599874  9160347307   05/01/2020            897              PPP
# 599875  8452318607   03/24/2021            897              PPP
# 599876  5991058901   05/01/2021            897              PPP
# 599877  6164058608   03/20/2021            897              PPP
# 599878  5170998610   03/20/2021            897              PPP
#
#                                        BorrowerName  \
# 0                                           APEX MD
# 1        1ST AMERICAN HOME HEALTH CARE SERVICESINC.
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 599871 entries, 0 to 599878
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   LoanNumber                   599871 non-null  int64
#  1   DateApproved                 599871 non-null  object
#  2   SBAOfficeCode                599871 non-null  int64
#  3   ProcessingMethod             599871 non-null  object
#  4   BorrowerName                 599871 non-null  object
#  5   BorrowerAddress              599865 non-null  object
#  6   BorrowerCity                 599866 non-null  object
#  7   BorrowerState                599871 non-null  object
#  8   BorrowerZip                  599866 non-null  object
#  9   LoanStatusDate               549771 non-null  object
#  10  LoanStatus                   599871 non-null  object
#  11  Term                         599871 non-null  int64
# ...

# %%
#add a few more colums to our df for analusis
df['year_approved'] = pd.DatetimeIndex(df['DateApproved']).year
df['month_approved'] = pd.DatetimeIndex(df['DateApproved']).month

df['year_forgiven'] = pd.DatetimeIndex(df['ForgivenessDate']).year
df['month_forgiven'] = pd.DatetimeIndex(df['ForgivenessDate']).month

# %%
df
# Out:
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0       7803247307   04/30/2020            304              PPP
# 1       7890008407   02/12/2021            353              PPS
# 2       8235537001   04/08/2020            304              PPP
# 3       8336827200   04/28/2020            304              PPP
# 4       8497097305   05/01/2020            304              PPP
# ...            ...          ...            ...              ...
# 599874  9160347307   05/01/2020            897              PPP
# 599875  8452318607   03/24/2021            897              PPP
# 599876  5991058901   05/01/2021            897              PPP
# 599877  6164058608   03/20/2021            897              PPP
# 599878  5170998610   03/20/2021            897              PPP
#
#                                        BorrowerName  \
# 0                                           APEX MD
# 1        1ST AMERICAN HOME HEALTH CARE SERVICESINC.
# ...

# %%
df.loc[df['ProcessingMethod'] == 'PPP'] #PPP is Loan ProcessingMethos
# Out:
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0       7803247307   04/30/2020            304              PPP
# 2       8235537001   04/08/2020            304              PPP
# 3       8336827200   04/28/2020            304              PPP
# 4       8497097305   05/01/2020            304              PPP
# 5       8634017006   04/08/2020            304              PPP
# ...            ...          ...            ...              ...
# 599874  9160347307   05/01/2020            897              PPP
# 599875  8452318607   03/24/2021            897              PPP
# 599876  5991058901   05/01/2021            897              PPP
# 599877  6164058608   03/20/2021            897              PPP
# 599878  5170998610   03/20/2021            897              PPP
#
#                                        BorrowerName        BorrowerAddress  \
# 0                                           APEX MD   5310 Twin Hickory Rd
# ...

# %%
df.loc[df['ProcessingMethod'] == 'PPS']
# Out:
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 1       7890008407   02/12/2021            353              PPS
# 13      4341258405   02/06/2021            353              PPS
# 15      5947758510   03/02/2021            304              PPS
# 18      6759308305   01/27/2021            304              PPS
# 19      6429808408   02/10/2021            304              PPS
# ...            ...          ...            ...              ...
# 599801  2687409004   05/18/2021            897              PPS
# 599817  1175178503   02/18/2021            897              PPS
# 599848  8101818907   05/11/2021            897              PPS
# 599850  1181968304   01/16/2021            897              PPS
# 599852  1486358310   01/17/2021            897              PPS
#
#                                       BorrowerName  \
# 1       1ST AMERICAN HOME HEALTH CARE SERVICESINC.
# 13                        NOVA FOOT AND ANKLE PLLC
# ...

# %%
FirstRound = df.loc[df['ProcessingMethod'] == 'PPP'] # name given for data frame

# %%
SecondRound = df.loc[df['ProcessingMethod'] == 'PPS']

# %%
FirstRound.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  7803247307   04/30/2020            304              PPP
# 2  8235537001   04/08/2020            304              PPP
# 3  8336827200   04/28/2020            304              PPP
# 4  8497097305   05/01/2020            304              PPP
# 5  8634017006   04/08/2020            304              PPP
#
#                                   BorrowerName        BorrowerAddress  \
# 0                                      APEX MD   5310 Twin Hickory Rd
# 2             QUALITY LANDSCAPE SOLUTIONS, LLC  14637 HOLDING POND CT
# 3                       EATS NATURAL FOODS INC     708A North MAIN ST
# 4  DETAIL JANITORIAL SERVICES OF VIRGINIA INC.        836 CALLAWAY RD
# 5                       LZD ENTERTAINMENT, LLC     14346 WARWICK BLVD
#
#    BorrowerCity BorrowerState BorrowerZip LoanStatusDate    LoanStatus  Term  \
# 0    GLEN ALLEN            VA       23059     03/19/2021  Paid in Full    24
# ...

# %% [markdown]
# # Categorical Variables

# %% [markdown]
# ## Univariable

# %%
# Count the how many records there are in each processing method
sns.countplot(df['ProcessingMethod'])
# Out:
# C:\Users\Kalyan Sabbarapu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ProcessingMethod', ylabel='count'>

# %%
sns.countplot(df['BorrowerState'])
# Out:
# C:\Users\Kalyan Sabbarapu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='BorrowerState', ylabel='count'>

# %%
sns.countplot(df['LoanStatus'])
# Out:
# C:\Users\Kalyan Sabbarapu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LoanStatus', ylabel='count'>

# %%
sns.countplot(df['Ethnicity'])
# Out:
# C:\Users\Kalyan Sabbarapu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Ethnicity', ylabel='count'>

# %%
#Rotate the ticklabbles
plt.figure(figsize=(15,6)) # this crates a figure 8 inch wide, 4 inch high
ax = sns.countplot(x="BusinessType", data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#plt.tight_Layout()
plt.show()

# %%
#Rotate the ticklabbles
# this crates a figure 8 inch wide, 4 inch high is missing
ax = sns.countplot(x="Race", data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#plt.tight_Layout()
plt.show()

# %% [markdown]
# # BiVariable

# %%
## Plotting Ethinicity Against Loan Status
sns.countplot(x ='Ethnicity', hue='LoanStatus', data = df)
# Out:
# <AxesSubplot:xlabel='Ethnicity', ylabel='count'>

# %%
#cross tabulation
pd.crosstab(df['BorrowerState'], df['Ethnicity'])
# Out:
# Ethnicity      Hispanic or Latino  Not Hispanic or Latino  Unknown/NotStated
# BorrowerState
# VA                           2753                   39449             139714
# VI                            163                     891               2059
# VT                             74                    4990              14366
# WA                           3661                   40170             127649
# WI                           1761                   47726             120977
# WV                            158                    9499              20295
# WY                            403                    6095              17018

# %%
pd.crosstab(df['year_approved'], df['BorrowerState'])
# Out:
# BorrowerState     VA    VI     VT     WA     WI     WV     WY
# year_approved
# 2020           86730  1864  10785  90871  76659  15687  12161
# 2021           95186  1249   8645  80609  93805  14265  11355

# %%
pd.crosstab(df['Ethnicity'], df['LoanStatus'])
# Out:
# LoanStatus              Active Un-Disbursed  Exemption 4  Paid in Full
# Ethnicity
# Hispanic or Latino                        0         1020          7953
# Not Hispanic or Latino                    4        12651        136165
# Unknown/NotStated                         3        36429        405646

# %% [markdown]
# ###  Numerical Variables - Discrete Variable

# %%
# Descriptive Summary
df['CurrentApprovalAmount'].describe()
# Out:
# count    599871.000000
# mean      27250.259802
# std       28315.811342
# min           1.800000
# 25%        8600.000000
# 50%       19377.000000
# 75%       33327.000000
# max      149999.990000
# Name: CurrentApprovalAmount, dtype: float64

# %% [markdown]
# ### Outliers

# %%
sns.boxplot(x = df['CurrentApprovalAmount'] )
# Out:
# <AxesSubplot:xlabel='CurrentApprovalAmount'>

# %%
plt.figure(figsize=(12,6)) # this creates a figure 8 inch wide, 4 inch high
sns.boxplot(x="LoanStatus", y="CurrentApprovalAmount", data=df)
# Out:
# <AxesSubplot:xlabel='LoanStatus', ylabel='CurrentApprovalAmount'>

# %%
sns.displot(df['CurrentApprovalAmount'])

# %%
sns.displot(df['CurrentApprovalAmount']/10**3)

# %%
df['CurrentApprovalAmount'].skew()
# Out:
# 1.958542058839005

# %%
df['CurrentApprovalAmount'].kurt()
# Out:
# 3.808650182874175

# %%
#Matrix Heat Map

matrix = df.corr()

# %%
f, ax = plt.subplots(figsize = (16,12))
sns.heatmap(matrix, annot = True)
# Out:
# <AxesSubplot:>
